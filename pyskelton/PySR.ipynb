# %%
import numpy as np
from pysr import PySRRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
X = 2 * np.random.randn(100, 5)
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 10.5 * X[:, 1]/X[:, 0]

# %%
model = PySRRegressor(
    niterations=100,  # < Increase me for better results
    binary_operators=["+", "*", "/"],
    unary_operators=[
        "cos",
        "exp",
        "sin",
        "inv(x) = 1/x",
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    loss="loss(x, y) = (x - y)^2",
    # ^ Custom loss function (julia syntax)
    temp_equation_file=True,
    delete_tempfiles=True
)

# %%
model.fit(X, y)
# Out:
# Started!
#
# Cycles per second: 2.130e+05
# Head worker occupation: 8.1%
# Progress: 587 / 1500 total iterations (39.133%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.375e+03  1.371e-02  x1
# 2           9.052e+03  3.511e-02  inv(x0)
# 3           5.202e+03  5.539e-01  (17.911634 / x0)
# 5           3.736e+01  2.468e+00  ((x1 * -10.521246) / x0)
# 7           2.286e+01  2.457e-01  (((x1 * -10.554308) / x0) + 3.820822)
# 9           2.918e+00  1.029e+00  (((x1 * -10.522607) / x0) + (x0 * x0))
# 11          2.818e+00  1.752e-02  ((((x1 * -10.525754) / x0) + (x0 * x0)) + 0.3180008)
# 12          1.135e+00  9.094e-01  ((((x1 * -10.541099) / x0) + cos(x3)) + (x0 * x0))
# 14          2.910e-01  6.805e-01  ((((x1 * -10.541099) / x0) + (cos(x3) * 1.9005889)) + (x0 * x0))
# 16          2.831e-01  1.375e-02  ((((x1 * -10.541099) / x0) + ((cos(x3) + 0.025587847) * 1.9005889)) + (x0 * x0))
# 18          1.716e-01  2.502e-01  ((((x1 * -10.541099) / x0) + ((cos(x3) / (x3 * 0.4510443)) * x3)) + (x0 * x0))
# 19          1.565e-01  9.212e-02  ((((x1 * -10.541099) / x0) + ((cos(x3) / (x3 * sin(0.4510443))) * x3)) + (x0 * x0))
# 20          1.471e-01  6.196e-02  ((((x1 * -10.541099) / x0) + ((cos(x3) / (x3 * sin(sin(0.4510443)))) * x3)) + (x0 * x0))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 2.150e+05
# Head worker occupation: 8.2%
# Progress: 1187 / 1500 total iterations (79.133%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.375e+03  1.371e-02  x1
# 2           9.052e+03  3.511e-02  inv(x0)
# 3           5.202e+03  5.539e-01  (17.911634 / x0)
# 5           3.736e+01  2.468e+00  ((x1 * -10.521246) / x0)
# 7           2.286e+01  2.457e-01  (((x1 * -10.554308) / x0) + 3.820822)
# 9           2.918e+00  1.029e+00  (((x1 * -10.522607) / x0) + (x0 * x0))
# 11          2.818e+00  1.752e-02  ((((x1 * -10.525754) / x0) + (x0 * x0)) + 0.3180008)
# 12          1.084e+00  9.556e-01  ((((x1 * -10.525754) / x0) + (x0 * x0)) + cos(x3))
# 14          9.140e-02  1.236e+00  ((((x1 * -10.525754) / x0) + (cos(x3) / 0.4510443)) + (x0 * x0))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                                 x1
# 	1         0.035113                                            inv(x0)
# 	2         0.553919                                   (17.911634 / x0)
# 	3         2.468032                           ((x1 * -10.521246) / x0)
# 	4         0.245729              (((x1 * -10.554308) / x0) + 3.820822)
# 	5         1.029185             (((x1 * -10.523049) / x0) + (x0 * x0))
# 	6         0.017521  ((((x1 * -10.525754) / x0) + (x0 * x0)) + 0.31...
# 	7         0.955560  ((((x1 * -10.525754) / x0) + (x0 * x0)) + cos(...
# 	8         1.236382  ((((x1 * -10.525754) / x0) + (cos(x3) / 0.4510...
# 	9   >>>>  0.234497  ((((x1 * -10.525754) / x0) + ((cos(x3) / 0.451...
# 	10        0.012991  ((((x1 * -10.525754) / x0) + ((cos(x3) / sin(0...
#
# 	           loss  complexity
# 	0   9375.225000           1
# 	1   9051.746000           2
# 	2   5201.978500           3
# 	3     37.364826           5
# 	4     22.857310           7
# 	5      2.918010           9
# 	6      2.817528          11
# 	7      1.083612          12
# 	8      0.091404          14
# 	9      0.057185          16
# 	10     0.056447          17
# ]

# %%
eq = model.equations_.sort_values('loss').reset_index(drop=True)[['equation', 'loss', 'complexity', 'score']]
eq
# Out:
#                                              equation         loss  \
# 0   ((((x1 * -10.525754) / x0) + ((cos(x3) / sin(0...     0.056447
# 1   ((((x1 * -10.525754) / x0) + ((cos(x3) / 0.451...     0.057185
# 2   ((((x1 * -10.525754) / x0) + (cos(x3) / 0.4510...     0.091404
# 3   ((((x1 * -10.525754) / x0) + (x0 * x0)) + cos(...     1.083612
# 4   ((((x1 * -10.525754) / x0) + (x0 * x0)) + 0.31...     2.817528
# 5              (((x1 * -10.523049) / x0) + (x0 * x0))     2.918010
# 6               (((x1 * -10.554308) / x0) + 3.820822)    22.857310
# 7                            ((x1 * -10.521246) / x0)    37.364826
# 8                                    (17.911634 / x0)  5201.978500
# 9                                             inv(x0)  9051.746000
# 10                                                 x1  9375.225000
#
#     complexity     score
# 0           17  0.012991
# 1           16  0.234497
# 2           14  1.236382
# 3           12  0.955560
# 4           11  0.017521
# 5            9  1.029185
# 6            7  0.245729
# 7            5  2.468032
# 8            3  0.553919
# 9            2  0.035113
# 10           1  0.000000

# %%
print(eq.loc[2,'equation'])
# Out:
# ((((x1 * -10.525754) / x0) + (cos(x3) / 0.4510443)) + (x0 * x0))

# %%
1/0.4510443
# Out:
# 2.217077125240248
